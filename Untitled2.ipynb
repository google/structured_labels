# %%
# %load_ext autoreload
# %autoreload 2
import tensorflow as tf 
import numpy as np 
import matplotlib.pyplot as plt
from cmnist.data_builder_new import *
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
data_fns = build_input_fns(p_tr=.7, py0=0.5, py1_y0=0.8, py1_y0_s=[.5], pflip0=.1,
	pflip1=.1, npix=20, oracle_prop=0.0, Kfolds=0, random_seed=0, n=1e5)
# Out:
# ==== length of training data 700========
# ==== length of full train x: 60000, y: 60000
# ==== length after dropping non 3/4 train x: 11973, y: 11973
# ==== length of subset train x: 700, y: 700
# Y0: true mean 0.4685714285714286, noisy 0.4542857142857143
# Y1: true mean 0.48428571428571426, noisy 0.49
# Got npix 20
# 100%|██████████| 700/700 [00:01<00:00, 588.43it/s]
# ====train xtab between the two labels=====
# y1         0         1
# y0
# 0   0.381429  0.164286
# 1   0.128571  0.325714
# ====train values of balanced weights=====
# 0.729663    267
# 0.683421    228
# 1.627652    115
# 1.802000     90
# Name: balanced_weights, dtype: int64
# ==== length of training data 300========
# ==== length of full validation x: 60000, y: 60000
# ==== length after dropping non 3/4 validation x: 11973, y: 11973
# ==== length of subset validation x: 300, y: 300
# Y0: true mean 0.49666666666666665, noisy 0.51
# Y1: true mean 0.49666666666666665, noisy 0.48333333333333334
# Got npix 20
# ...

# %%
training_data_size, train_input_fn, valid_input_fn, Kfold_input_fn_creater, eval_input_fn_creater = data_fns

# %%
train_data = train_input_fn({'batch_size':100, 'num_epochs': 1})
# Out:
# Tensor("strided_slice:0", shape=(), dtype=string)

# %%
for batch_id, data in enumerate(train_data):
    if batch_id > 0: 
        break
    images, labels_weights = data

# %%
for i in range(50):
    plt.figure(figsize=(5,5))
    plt.imshow(images[i, :, :])
    y0 = labels_weights['labels'][i, 0]
    y1 = labels_weights['labels'][i, 1]
    plt.title(f'y: {int(y0)}, v {int(y1)}')
# Out:
# <ipython-input-58-b3fd9cbd4305>:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(5,5))
